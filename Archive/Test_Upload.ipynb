# %%
print("This is just to check if everything is working!")
# Out:
# This is just to check if everything is working!

# %%
#checking again if inline plots are working

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def rad_to_degrees(x, pos):
    'converts radians to degrees'
    return round(x * 57.2985, 2)

plt.figure(figsize=(10,6), dpi=100)
X = np.linspace(0,2*np.pi,1000)
plt.plot(X,np.sin(X))
plt.plot(X,np.cos(X))

# %%
print("Yay!")
# Out:
# Yay!
